# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/Mental Health Dataset.csv")
data.head(10)
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
# 5  8/27/2014 11:49  Female         Poland  Corporate            No
# 6  8/27/2014 11:51  Female      Australia  Corporate            No
# 7  8/27/2014 11:52  Female  United States  Corporate            No
# 8  8/27/2014 12:18  Female  United States  Corporate            No
# 9  8/27/2014 12:37  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
# 5             No       Yes    1-14 days            Yes             No
# 6            Yes       Yes    1-14 days            Yes             No
# 7             No        No    1-14 days            Yes             No
# 8             No        No    1-14 days            Yes             No
# 9             No        No    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
# 2                   Yes      Medium               No            No
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
# 5                   Yes      Medium               No            No
# 6                   Yes      Medium               No            No
# 7                   Yes      Medium               No            No
# 8                   Yes      Medium               No            No
# 9                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options
# 0             Yes                      No     Not sure
# 1             Yes                      No           No
# 2             Yes                      No          Yes
# 3             Yes                   Maybe          Yes
# 4             Yes                      No          Yes
# 5             Yes                   Maybe     Not sure
# 6             Yes                      No     Not sure
# 7             Yes                      No           No
# 8             Yes                      No     Not sure
# 9             Yes                      No           No

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77708 entries, 0 to 77707
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                77708 non-null  object
#  1   Gender                   77708 non-null  object
#  2   Country                  77708 non-null  object
#  3   Occupation               77707 non-null  object
#  4   self_employed            75995 non-null  object
#  5   family_history           77707 non-null  object
#  6   treatment                77707 non-null  object
#  7   Days_Indoors             77707 non-null  object
#  8   Growing_Stress           77707 non-null  object
#  9   Changes_Habits           77707 non-null  object
#  10  Mental_Health_History    77707 non-null  object
#  11  Mood_Swings              77707 non-null  object
#  12  Coping_Struggles         77707 non-null  object
#  13  Work_Interest            77707 non-null  object
#  14  Social_Weakness          77707 non-null  object
#  15  mental_health_interview  77707 non-null  object
#  16  care_options             77707 non-null  object
# dtypes: object(17)
# memory usage: 10.1+ MB

# %%
data.isna().mean()*100
# Out:
# Timestamp                  0.000000
# Gender                     0.000000
# Country                    0.000000
# Occupation                 0.001287
# self_employed              2.204406
# family_history             0.001287
# treatment                  0.001287
# Days_Indoors               0.001287
# Growing_Stress             0.001287
# Changes_Habits             0.001287
# Mental_Health_History      0.001287
# Mood_Swings                0.001287
# Coping_Struggles           0.001287
# Work_Interest              0.001287
# Social_Weakness            0.001287
# mental_health_interview    0.001287
# care_options               0.001287
# dtype: float64

# %%
data.dropna(subset=["self_employed"],inplace=True)

# %%
print("duplicated",data.duplicated().mean()*100)
data.drop_duplicates(inplace=True)
# Out:
# duplicated 0.7355747088624252

# %%
print("duplicated",data.duplicated().mean()*100)
data.drop_duplicates(inplace=True)
# Out:
# duplicated 0.0

# %%
data.head(10).T
# Out:
#                                       3                4                5   \
# Timestamp                8/27/2014 11:37  8/27/2014 11:43  8/27/2014 11:49
# Gender                            Female           Female           Female
# Country                    United States    United States           Poland
# Occupation                     Corporate        Corporate        Corporate
# self_employed                         No               No               No
# family_history                       Yes              Yes               No
# treatment                            Yes              Yes              Yes
# Days_Indoors                   1-14 days        1-14 days        1-14 days
# Growing_Stress                       Yes              Yes              Yes
# Changes_Habits                        No               No               No
# Mental_Health_History                Yes              Yes              Yes
# Mood_Swings                       Medium           Medium           Medium
# Coping_Struggles                      No               No               No
# Work_Interest                         No               No               No
# Social_Weakness                      Yes              Yes              Yes
# mental_health_interview            Maybe               No            Maybe
# care_options                         Yes              Yes         Not sure
#
#                                       6                7                8   \
# Timestamp                8/27/2014 11:51  8/27/2014 11:52  8/27/2014 12:18
# Gender                            Female           Female           Female
# Country                        Australia    United States    United States
# Occupation                     Corporate        Corporate        Corporate
# self_employed                         No               No               No
# family_history                       Yes               No               No
# treatment                            Yes               No               No
# Days_Indoors                   1-14 days        1-14 days        1-14 days
# Growing_Stress                       Yes              Yes              Yes
# Changes_Habits                        No               No               No
# Mental_Health_History                Yes              Yes              Yes
# Mood_Swings                       Medium           Medium           Medium
# Coping_Struggles                      No               No               No
# Work_Interest                         No               No               No
# Social_Weakness                      Yes              Yes              Yes
# mental_health_interview               No               No               No
# care_options                    Not sure               No         Not sure
#
#                                       9                10               11  \
# Timestamp                8/27/2014 12:37  8/27/2014 12:39  8/27/2014 12:40
# Gender                            Female           Female           Female
# Country                    United States    United States    United States
# Occupation                     Corporate        Corporate        Corporate
# self_employed                         No               No               No
# family_history                        No              Yes               No
# treatment                             No               No               No
# Days_Indoors                   1-14 days        1-14 days        1-14 days
# Growing_Stress                       Yes              Yes              Yes
# Changes_Habits                        No               No               No
# Mental_Health_History                Yes              Yes              Yes
# Mood_Swings                       Medium           Medium           Medium
# Coping_Struggles                      No               No               No
# Work_Interest                         No               No               No
# Social_Weakness                      Yes              Yes              Yes
# mental_health_interview               No               No               No
# care_options                          No         Not sure         Not sure
#
#                                       12
# Timestamp                8/27/2014 12:49
# Gender                            Female
# Country                    United States
# Occupation                     Corporate
# self_employed                         No
# family_history                        No
# treatment                             No
# Days_Indoors                   1-14 days
# Growing_Stress                       Yes
# Changes_Habits                        No
# Mental_Health_History                Yes
# Mood_Swings                       Medium
# Coping_Struggles                      No
# Work_Interest                         No
# Social_Weakness                      Yes
# mental_health_interview               No
# care_options                          No

# %%
data["Timestamp"]=pd.to_datetime(data.Timestamp)
data["Years"]=data["Timestamp"].dt.year

# %%
data["month"]=data["Timestamp"].dt.month
data["day"]=data["Timestamp"].dt.day_name

# %%
data.dtypes
# Out:
# Timestamp                  datetime64[ns]
# Gender                             object
# Country                            object
# Occupation                         object
# self_employed                      object
# family_history                     object
# treatment                          object
# Days_Indoors                       object
# Growing_Stress                     object
# Changes_Habits                     object
# Mental_Health_History              object
# Mood_Swings                        object
# Coping_Struggles                   object
# Work_Interest                      object
# Social_Weakness                    object
# mental_health_interview            object
# care_options                       object
# Years                               int32
# month                               int32
# day                                object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
sns.countplot(data=data,x="Gender",)
plt.title('Distribution of Gender in Mental Health Data')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data=data,x="Country",)
plt.xticks(rotation=90)
plt.title('Distribution of Countries in Mental Health Data')
plt.show()

# %%
sns.countplot(data=data,x="Occupation")
plt.title('Distribution of Occupation in Mental Health Data')
plt.show()

# %%
sns.countplot(data=data,x="self_employed")
plt.title('Distribution of Occupation in Mental Health Data')
plt.show()

# %%
data.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Mood_Swings',
#        'Coping_Struggles', 'Work_Interest', 'Social_Weakness',
#        'mental_health_interview', 'care_options', 'Years', 'month', 'day'],
#       dtype='object')

# %%
genderBycountery=data.groupby("Country")["Gender"].value_counts().unstack(fill_value=0)
genderBycountery
# Out:
# Gender                  Female   Male
# Country
# Australia                 1724    450
# Belgium                    431     41
# Bosnia and Herzegovina       0     41
# Brazil                       0    246
# Canada                    3879   1434
# Colombia                     0     41
# Costa Rica                   0     41
# Croatia                      0     41
# Czech Republic               0     41
# Denmark                      0     82
# Finland                      0     41
# France                       0    246
# Georgia                      0     41
# Germany                      0    492
# Greece                       0     81
# India                      431    246
# Ireland                    862    491
# Israel                       0    164
# Italy                        0    164
# Mexico                       0     41
# Moldova                      0     41
# Netherlands                431    573
# New Zealand                431    164
# Nigeria                      0     41
# Philippines                  0     40
# Poland                     431     40
# Portugal                     0     41
# Russia                       0     82
# Singapore                    0     82
# South Africa               431    163
# Sweden                     862    205
# Switzerland                  0    164
# Thailand                     0     41
# United Kingdom            6896   4589
# United States            34049  13847

# %%
genderBycountery["Total"]=genderBycountery.sum(axis=1)

# %%
genderBycountery
# Out:
# Gender                  Female   Male  Total
# Country
# Australia                 1724    450   2174
# Belgium                    431     41    472
# Bosnia and Herzegovina       0     41     41
# Brazil                       0    246    246
# Canada                    3879   1434   5313
# Colombia                     0     41     41
# Costa Rica                   0     41     41
# Croatia                      0     41     41
# Czech Republic               0     41     41
# Denmark                      0     82     82
# Finland                      0     41     41
# France                       0    246    246
# Georgia                      0     41     41
# Germany                      0    492    492
# Greece                       0     81     81
# India                      431    246    677
# Ireland                    862    491   1353
# Israel                       0    164    164
# Italy                        0    164    164
# Mexico                       0     41     41
# Moldova                      0     41     41
# Netherlands                431    573   1004
# New Zealand                431    164    595
# Nigeria                      0     41     41
# Philippines                  0     40     40
# Poland                     431     40    471
# Portugal                     0     41     41
# Russia                       0     82     82
# Singapore                    0     82     82
# South Africa               431    163    594
# Sweden                     862    205   1067
# Switzerland                  0    164    164
# Thailand                     0     41     41
# United Kingdom            6896   4589  11485
# United States            34049  13847  47896

# %%
gender_stress_counts=data.Gender.value_counts()
print(f"gender_stress_counts {gender_stress_counts} \n")

genderBy_stress=data.groupby("Gender")["Growing_Stress"].value_counts().unstack()
genderBy_stress
# Out:
# gender_stress_counts Gender
# Female    50858
# Male      24578
# Name: count, dtype: int64
# Growing_Stress  Maybe     No    Yes
# Gender
# Female          15340  15340  20178
# Male             9600   6578   8400

# %%
data.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Mood_Swings',
#        'Coping_Struggles', 'Work_Interest', 'Social_Weakness',
#        'mental_health_interview', 'care_options', 'Years', 'month', 'day'],
#       dtype='object')

# %%
OccupationBy_stress=data.groupby("Occupation")["Growing_Stress"].value_counts().unstack()
OccupationBy_stress
# Out:
# Growing_Stress  Maybe    No   Yes
# Occupation
# Business         3432  3068  5222
# Corporate        5232  4042  4740
# Housewife        6176  5210  5320
# Others           4750  4750  7130
# Student          5350  4848  6166

# %%
OccupationBy_gender_stress=data.groupby(["Occupation","Gender"])["Growing_Stress"].value_counts().unstack()
OccupationBy_gender_stress
# Out:
# Growing_Stress      Maybe      No     Yes
# Occupation Gender
# Business   Female  2832.0  3068.0  3422.0
#            Male     600.0     NaN  1800.0
# Corporate  Female  2832.0  2242.0  3540.0
#            Male    2400.0  1800.0  1200.0
# Housewife  Female  3776.0  2832.0  4720.0
#            Male    2400.0  2378.0   600.0
# Others     Female  2950.0  2950.0  4130.0
#            Male    1800.0  1800.0  3000.0
# Student    Female  2950.0  4248.0  4366.0
#            Male    2400.0   600.0  1800.0

# %%
OccupationBy_gender_stress["Total"]=OccupationBy_gender_stress.sum(axis=1)
OccupationBy_gender_stress
# Out:
# Growing_Stress      Maybe      No     Yes    Total
# Occupation Gender
# Business   Female  2832.0  3068.0  3422.0   9322.0
#            Male     600.0     NaN  1800.0   2400.0
# Corporate  Female  2832.0  2242.0  3540.0   8614.0
#            Male    2400.0  1800.0  1200.0   5400.0
# Housewife  Female  3776.0  2832.0  4720.0  11328.0
#            Male    2400.0  2378.0   600.0   5378.0
# Others     Female  2950.0  2950.0  4130.0  10030.0
#            Male    1800.0  1800.0  3000.0   6600.0
# Student    Female  2950.0  4248.0  4366.0  11564.0
#            Male    2400.0   600.0  1800.0   4800.0

# %%
occupation_gender_stress_prop = OccupationBy_gender_stress.div(OccupationBy_gender_stress['Total'], axis=0)
occupation_gender_stress_prop = occupation_gender_stress_prop.drop('Total', axis=1)
occupation_gender_stress_prop
# Out:
# Growing_Stress        Maybe        No       Yes
# Occupation Gender
# Business   Female  0.303797  0.329114  0.367089
#            Male    0.250000       NaN  0.750000
# Corporate  Female  0.328767  0.260274  0.410959
#            Male    0.444444  0.333333  0.222222
# Housewife  Female  0.333333  0.250000  0.416667
#            Male    0.446263  0.442172  0.111566
# Others     Female  0.294118  0.294118  0.411765
#            Male    0.272727  0.272727  0.454545
# Student    Female  0.255102  0.367347  0.377551
#            Male    0.500000  0.125000  0.375000

# %%
sns.heatmap(occupation_gender_stress_prop,annot=True,cmap="YlGnBu")
plt.xlabel("Growing Stress")
plt.ylabel("Occupation-Gender")
plt.title("Proportion of Growing Stress by Occupation and Gender")
plt.show()

# %%
treatment_by_gender = data.groupby('Gender')['treatment'].value_counts(normalize=True).unstack() * 100
print(treatment_by_gender)

treatment_by_gender.plot(kind='bar', stacked=True, colormap='viridis')
plt.ylabel('Percentage')
plt.title('Mental Health Treatment by Gender')
plt.show()
# Out:
# treatment         No        Yes
# Gender
# Female     31.355932  68.644068
# Male       53.690292  46.309708

# %%
treatment_by_country = data.groupby('Country')['treatment'].value_counts(normalize=True).unstack() * 100
treatment_by_country.plot(kind='bar', stacked=True, colormap='Set2', figsize=(12,6))
plt.ylabel('Percentage')
plt.title('Mental Health Treatment by Country (Top 10)')
plt.xticks(rotation=45)
plt.show()

# %%
crosstab = pd.crosstab(data['self_employed'], data['treatment'], normalize='index') * 100
print(crosstab)

crosstab.plot(kind='bar', stacked=True, )
plt.ylabel('Percentage')
plt.title('Self-employed vs. Mental Health Treatment')
plt.show()
# Out:
# treatment             No        Yes
# self_employed
# No             39.885754  60.114246
# Yes            23.481430  76.518570
